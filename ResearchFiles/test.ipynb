# %%
import gpytorch
import torch
import numpy as np
import matplotlib.pyplot as plt
from botorch.models import SingleTaskGP
from botorch.fit import fit_gpytorch_mll
from botorch.utils import standardize
from gpytorch.mlls import ExactMarginalLogLikelihood
from tqdm import trange
import pandas as pd
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.models import ApproximateGP
from gpytorch.variational import VariationalStrategy, CholeskyVariationalDistribution
from gpytorch.kernels import ScaleKernel, RBFKernel
from gpytorch.means import ConstantMean
from gpytorch.likelihoods import GaussianLikelihood, StudentTLikelihood
from gpytorch.mlls import VariationalELBO
import math

# Check for MPS and CUDA device availability
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("MPS device found, setting as device.")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA device found, setting as device.")
else:
    device = torch.device("cpu")
    print("Neither MPS nor CUDA device found. Using default device (CPU).")

# Set the seed for all random uses
def set_seeds(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)

set_seeds(22)
seed = 22

# Initial setup
training_iterations = 20
num_initial_points = 3
num_new_samples_per_iteration = 1
total_samples = 200
acqFunc = "UCB"
max_or_min = 'max'

# Create the training data
set_seeds(0)
X = np.linspace(0.0, np.pi * 2, total_samples)[:, None]
Y = np.sin(X)
cauchy_noise = np.random.standard_cauchy(Y.shape) * 0.06
Yc = Y + cauchy_noise
Yc = Yc / Yc.max()
X = X / X.max()
Yc[75:80] += 1

train_x = torch.from_numpy(X.ravel()).to(dtype=torch.float64)
train_y = torch.from_numpy(Yc.ravel()).to(dtype=torch.float64)

indicesSTP = torch.randperm(total_samples)[:num_initial_points]
indicesEGP = indicesSTP
indicesVGP = indicesSTP

train_xSTP = train_x[indicesSTP]
train_ySTP = train_y[indicesSTP]
train_xEGP = train_xSTP
train_yEGP = train_ySTP
train_xVGP = train_xSTP
train_yVGP = train_ySTP
initialPoints = train_xSTP
initialPointsy = train_ySTP

# Preprocessing classes
class TorchStandardScaler:
    def fit(self, x):
        self.mean = x.mean(0, keepdim=True)
        self.std = x.std(0, unbiased=False, keepdim=True)

    def transform(self, x):
        return (x - self.mean) / (self.std + 1e-10)

    def fit_transform(self, x):
        self.fit(x)
        return self.transform(x)
    
class TorchNormalizer:
    def fit(self, x):
        self.max = torch.max(x, dim=0).values
        self.min = torch.min(x, dim=0).values

    def transform(self, x):
        return (x - self.min) / (self.max - self.min)

    def fit_transform(self, x):
        self.fit(x)
        return self.transform(x)

TorchStd = TorchStandardScaler()
TorchStd.fit(train_x)
TorchNorm = TorchNormalizer()
TorchNorm.fit(train_x)

N = len(train_x)
n_top = int(math.ceil(N * 0.05))

# Find the top 5% of the samples
if max_or_min == 'max':
    train_y_df = pd.DataFrame(train_y.numpy(), columns=[0])
    top_samples = train_y_df.nlargest(n_top, train_y_df.columns[0], keep='first').iloc[:, 0].values.tolist()
elif max_or_min == 'min':
    train_y_df = pd.DataFrame(train_y.numpy(), columns=[0])
    top_samples = train_y_df.nsmallest(n_top, train_y_df.columns[0], keep='first').iloc[:, 0].values.tolist()

def TopSamplesAmnt(y, top_samples):
    return len([i for i in y if i in top_samples]) / len(top_samples)

# Model classes
class STP(gpytorch.models.ApproximateGP):
    def __init__(self, inducing_points):
        variational_distribution = gpytorch.variational.CholeskyVariationalDistribution(inducing_points.size(0))
        variational_strategy = gpytorch.variational.VariationalStrategy(
            self, inducing_points, variational_distribution, learn_inducing_locations=False
        )
        super().__init__(variational_strategy)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class ExactGP(gpytorch.models.ExactGP):
    def __init__(self, x_train, y_train, likelihood):
        super(ExactGP, self).__init__(x_train, y_train, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        num_dimensions = x_train.shape[0]
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel(nu=2.5, ard_num_dims=num_dimensions))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class VariationalGP(ApproximateGP):
    def __init__(self, inducing_points):
        variational_distribution = CholeskyVariationalDistribution(inducing_points.size(0))
        variational_strategy = VariationalStrategy(self, inducing_points, variational_distribution, learn_inducing_locations=True)
        super(VariationalGP, self).__init__(variational_strategy)
        self.mean_module = ConstantMean()
        self.covar_module = ScaleKernel(RBFKernel(ard_num_dims=inducing_points.size(0)))

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# Acquisition functions
def UCB(mean, std, beta):
    return mean + beta * std

def LCB(mean, std, beta):
    return mean - beta * std

def EImin(mean, std, best_observed):
    z = (best_observed - mean) / std
    return (best_observed - mean) * torch.distributions.Normal(0, 1).cdf(z) + std * torch.distributions.Normal(0, 1).log_prob(z)

def EImax(mean, std, best_observed):
    z = (mean - best_observed) / std
    return (mean - best_observed) * torch.distributions.Normal(0, 1).cdf(z) + std * torch.distributions.Normal(0, 1).log_prob(z)

# Optimization loops for STP, EGP, and VGP models
# STP Optimization
iterationSTP = [0]
topSTP = [0]
set_seeds(22)

if max_or_min == "max":
    top_5_percent_threshold = torch.quantile(train_y, 0.95)
    non_top_5_indices = (train_y < top_5_percent_threshold).nonzero(as_tuple=True)[0]
elif max_or_min == "min":
    top_5_percent_threshold = torch.quantile(train_y, 0.05)
    non_top_5_indices = (train_y > top_5_percent_threshold).nonzero(as_tuple=True)[0]

indicesSTP = torch.randperm(len(non_top_5_indices))[:num_initial_points]
indicesSTP = non_top_5_indices[indicesSTP]

train_xSTP = train_x[indicesSTP]
train_ySTP = train_y[indicesSTP]

print(f"Seed: {seed}")
print(f"Initial points: {train_xSTP}")

while topSTP[-1] < 100:
    iterationSTP.append(iterationSTP[-1] + 1)
    train_xSTP = TorchStd.transform(train_xSTP)
    train_ySTP = TorchStandardScaler().fit_transform(train_ySTP).flatten()

    model = STP(train_xSTP).to(dtype=torch.float64)
    likelihood = gpytorch.likelihoods.StudentTLikelihood()
    objective_function = gpytorch.mlls.VariationalELBO(likelihood, model, num_data=train_ySTP.numel())
    optimizer = torch.optim.Adam(list(model.parameters()) + list(likelihood.parameters()), lr=0.1)

    model.train()
    likelihood.train()

    for _ in range(50):
        output = model(train_xSTP)
        loss = -objective_function(output, train_ySTP)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    model.eval()
    likelihood.eval()

    with gpytorch.settings.num_likelihood_samples(512):
        observed_pred = likelihood(model(TorchStd.transform(train_x)))

    samples = observed_pred.sample()
    meanSTP = samples.mean(dim=0)
    stdSTP = samples.std(dim=0)
    best = train_ySTP.max()

    if acqFunc == "UCB":
        ucb_values = UCB(meanSTP, stdSTP, 1.96)
        ucb_values[indicesSTP] = -float('inf')
        indicesSTP = torch.cat([indicesSTP, ucb_values.argmax().unsqueeze(0)])
    elif acqFunc == "LCB":
        lcb_values = LCB(meanSTP, stdSTP, best)
        lcb_values[indicesSTP] = -float('inf')
        indicesSTP = torch.cat([indicesSTP, lcb_values.argmax().unsqueeze(0)])
    elif acqFunc == "EImin":
        ei_min_values = EImin(meanSTP, stdSTP, best)
        ei_min_values[indicesSTP] = -float('inf')
        indicesSTP = torch.cat([indicesSTP, ei_min_values.argmax().unsqueeze(0)])
    elif acqFunc == "EImax":
        ei_max_values = EImax(meanSTP, stdSTP, best)
        ei_max_values[indicesSTP] = -float('inf')
        indicesSTP = torch.cat([indicesSTP, ei_max_values.argmax().unsqueeze(0)])
    else:
        print("Please change the acquisition function to UCB, LCB, EImax, or EImin in the setup")
        raise ValueError("Invalid acquisition function specified")

    train_xSTP = train_x[indicesSTP]
    train_ySTP = train_y[indicesSTP]
    topSTP.append(TopSamplesAmnt(train_ySTP, top_samples) * 100)

    if iterationSTP[-1] > len(train_x) - num_initial_points:
        print("Maximum number of iterations exceeded, breaking loop.")
        print(f'Iterations {iterationSTP[-1]}')
        break
    print(f"Iteration {iterationSTP[-1]}")
    print(f"New points: {train_xSTP[-1]}")
    print(f"Top 5%: {topSTP[-1]}")

print(f'Iterations {iterationSTP[-1]}')

# EGP Optimization
iterationEGP = [0]
topEGP = [0]
set_seeds(22)

if max_or_min == "max":
    top_5_percent_threshold = torch.quantile(train_y, 0.95)
    non_top_5_indices = (train_y < top_5_percent_threshold).nonzero(as_tuple=True)[0]
elif max_or_min == "min":
    top_5_percent_threshold = torch.quantile(train_y, 0.05)
    non_top_5_indices = (train_y > top_5_percent_threshold).nonzero(as_tuple=True)[0]

indicesEGP = torch.randperm(len(non_top_5_indices))[:num_initial_points]
indicesEGP = non_top_5_indices[indicesEGP]

train_xEGP = train_x[indicesEGP]
train_yEGP = train_y[indicesEGP]

print(f"Seed: {seed}")
print(f"Initial points: {train_xEGP}")

while topEGP[-1] < 100:
    iterationEGP.append(iterationEGP[-1] + 1)
    train_xEGP = TorchStd.transform(train_xEGP)
    train_yEGP = TorchStandardScaler().fit_transform(train_yEGP).flatten()

    likelihood = GaussianLikelihood(noise_prior=gpytorch.priors.HalfNormalPrior(0.01))
    gp = ExactGP(train_xEGP, train_yEGP, likelihood)
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, gp)

    gp.train()
    likelihood.train()
    fit_gpytorch_mll(mll)

    gp.eval()
    likelihood.eval()

    with torch.no_grad():
        pred = gp(TorchStd.transform(train_x))

    meanEGP = pred.mean
    stdEGP = pred.stddev
    best = train_yEGP.max()

    if acqFunc == "UCB":
        ucb_values = UCB(meanEGP, stdEGP, 1.96)
        ucb_values[indicesEGP] = -float('inf')
        indicesEGP = torch.cat([indicesEGP, ucb_values.argmax().unsqueeze(0)])
    elif acqFunc == "LCB":
        lcb_values = LCB(meanEGP, stdEGP, best)
        lcb_values[indicesEGP] = -float('inf')
        indicesEGP = torch.cat([indicesEGP, lcb_values.argmax().unsqueeze(0)])
    elif acqFunc == "EImin":
        ei_min_values = EImin(meanEGP, stdEGP, best)
        ei_min_values[indicesEGP] = -float('inf')
        indicesEGP = torch.cat([indicesEGP, ei_min_values.argmax().unsqueeze(0)])
    elif acqFunc == "EImax":
        ei_max_values = EImax(meanEGP, stdEGP, best)
        ei_max_values[indicesEGP] = -float('inf')
        indicesEGP = torch.cat([indicesEGP, ei_max_values.argmax().unsqueeze(0)])
    else:
        print("Please change the acquisition function to UCB, LCB, EImax, or EImin in the setup")
        raise ValueError("Invalid acquisition function specified")

    train_xEGP = train_x[indicesEGP]
    train_yEGP = train_y[indicesEGP]
    topEGP.append(TopSamplesAmnt(train_yEGP, top_samples) * 100)

    if iterationEGP[-1] > len(train_x) - num_initial_points:
        print("Maximum number of iterations exceeded, breaking loop.")
        print(f'Iterations {iterationEGP[-1]}')
        break

    print(f"Iteration {iterationEGP[-1]}")
    print(f"New points: {train_xEGP[-1]}")
    print(f"Top 5%: {topEGP[-1]}")

print(f'Iterations {iterationEGP[-1]}')

# VGP Optimization
iterationVGP = [0]
topVGP = [0]
set_seeds(22)

if max_or_min == "max":
    top_5_percent_threshold = torch.quantile(train_y, 0.95)
    non_top_5_indices = (train_y < top_5_percent_threshold).nonzero(as_tuple=True)[0]
elif max_or_min == "min":
    top_5_percent_threshold = torch.quantile(train_y, 0.05)
    non_top_5_indices = (train_y > top_5_percent_threshold).nonzero(as_tuple=True)[0]

indicesVGP = torch.randperm(len(non_top_5_indices))[:num_initial_points]
indicesVGP = non_top_5_indices[indicesVGP]

train_xVGP = train_x[indicesVGP]
train_yVGP = train_y[indicesVGP]

print(f"Seed: {seed}")
print(f"Initial points: {train_xSTP}")

while topVGP[-1] < 100:
    iterationVGP.append(iterationVGP[-1] + 1)
    train_xVGP = TorchStd.transform(train_xVGP)
    train_yVGP = TorchStandardScaler().fit_transform(train_yVGP).flatten()

    model = VariationalGP(train_xVGP).to(dtype=torch.float64)
    likelihood = GaussianLikelihood()
    objective_function = gpytorch.mlls.VariationalELBO(likelihood, model, num_data=train_yVGP.numel())
    optimizer = torch.optim.Adam(list(model.parameters()) + list(likelihood.parameters()), lr=0.1)

    model.train()
    likelihood.train()

    for _ in range(50):
        output = model(train_xVGP)
        loss = -objective_function(output, train_yVGP)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

    model.eval()
    likelihood.eval()

    with torch.no_grad():
        pred = model(TorchStd.transform(train_x))

    meanVGP = pred.mean
    stdVGP = pred.stddev
    best_observed_value = train_yVGP.min()

    if acqFunc == "UCB":
        ucb_values = UCB(meanVGP, stdVGP, 1.96)
        ucb_values[indicesVGP] = -float('inf')
        indicesVGP = torch.cat([indicesVGP, ucb_values.argmax().unsqueeze(0)])
    elif acqFunc == "LCB":
        lcb_values = LCB(meanVGP, stdVGP, best)
        lcb_values[indicesVGP] = -float('inf')
        indicesVGP = torch.cat([indicesVGP, lcb_values.argmax().unsqueeze(0)])
    elif acqFunc == "EImin":
        ei_min_values = EImin(meanVGP, stdVGP, best)
        ei_min_values[indicesVGP] = -float('inf')
        indicesVGP = torch.cat([indicesVGP, ei_min_values.argmax().unsqueeze(0)])
    elif acqFunc == "EImax":
        ei_max_values = EImax(meanVGP, stdVGP, best)
        ei_max_values[indicesVGP] = -float('inf')
        indicesVGP = torch.cat([indicesVGP, ei_max_values.argmax().unsqueeze(0)])
    else:
        print("Please change the acquisition function to UCB, LCB, EImax, or EImin in the setup")
        raise ValueError("Invalid acquisition function specified")

    train_xVGP = train_x[indicesVGP]
    train_yVGP = train_y[indicesVGP]
    topVGP.append(TopSamplesAmnt(train_yVGP, top_samples) * 100)

    if iterationVGP[-1] > len(train_x) - num_initial_points:
        print("Maximum number of iterations exceeded, breaking loop.")
        print(f"Reached {topVGP[-1]}%")
        break
    print(f"Iteration {iterationVGP[-1]}")
    print(f"New points: {train_xVGP[-1]}")
    print(f"Top 5%: {topVGP[-1]}")

print(f'Iterations {iterationVGP[-1]}')
# Out:
# CUDA device found, setting as device.
# Seed: 22
# Initial points: tensor([0.4422, 0.3719, 0.7186], dtype=torch.float64)
# Iteration 1
# New points: 0.21105527638190957
# Top 5%: 0.0
# Iteration 2
# New points: 0.005025125628140704
# Top 5%: 0.0
# Iteration 3
# New points: 0.2663316582914573
# Top 5%: 0.0
# Iteration 4
# New points: 0.2964824120603015
# Top 5%: 0.0
# Iteration 5
# New points: 0.2613065326633166
# Top 5%: 0.0
# Iteration 6
# New points: 0.2512562814070352
# Top 5%: 0.0
# Iteration 7
# New points: 0.271356783919598
# Top 5%: 0.0
# Iteration 8
# New points: 0.2864321608040201
# Top 5%: 0.0
# Iteration 9
# New points: 0.2562814070351759
# Top 5%: 0.0
# Iteration 10
# New points: 0.2763819095477387
# Top 5%: 0.0
# Iteration 11
# New points: 0.29145728643216084
# Top 5%: 0.0
# Iteration 12
# New points: 0.3065326633165829
# Top 5%: 0.0
# Iteration 13
# New points: 0.2361809045226131
# Top 5%: 0.0
# Iteration 14
# New points: 0.24623115577889446
# Top 5%: 0.0
# Iteration 15
# New points: 0.23115577889447236
# Top 5%: 0.0
# Iteration 16
# New points: 0.2412060301507538
# Top 5%: 0.0
# Iteration 17
# New points: 0.22613065326633167
# Top 5%: 0.0
# Iteration 18
# New points: 0.22110552763819094
# Top 5%: 0.0
# Iteration 19
# New points: 0.2814070351758794
# Top 5%: 0.0
# Iteration 20
# New points: 0.3015075376884422
# Top 5%: 0.0
# Iteration 21
# New points: 0.21608040201005024
# Top 5%: 0.0
# Iteration 22
# New points: 0.08542713567839197
# Top 5%: 0.0
# Iteration 23
# New points: 0.31658291457286436
# Top 5%: 0.0
# Iteration 24
# New points: 0.3266331658291457
# Top 5%: 0.0
# Iteration 25
# New points: 0.3768844221105528
# Top 5%: 10.0
# Iteration 26
# New points: 0.9698492462311559
# Top 5%: 10.0
# Iteration 27
# New points: 0.20603015075376885
# Top 5%: 10.0
# Iteration 28
# New points: 0.3618090452261307
# Top 5%: 10.0
# Iteration 29
# New points: 0.055276381909547735
# Top 5%: 10.0
# Iteration 30
# New points: 0.9648241206030151
# Top 5%: 10.0
# Iteration 31
# New points: 0.3668341708542714
# Top 5%: 10.0
# Iteration 32
# New points: 0.864321608040201
# Top 5%: 10.0
# Iteration 33
# New points: 0.5175879396984925
# Top 5%: 10.0
# Iteration 34
# New points: 0.31155778894472363
# Top 5%: 20.0
# Iteration 35
# New points: 0.8542713567839196
# Top 5%: 20.0
# Iteration 36
# New points: 0.0
# Top 5%: 20.0
# Iteration 37
# New points: 0.10050251256281408
# Top 5%: 20.0
# Iteration 38
# New points: 0.3316582914572864
# Top 5%: 20.0
# Iteration 39
# New points: 0.457286432160804
# Top 5%: 20.0
# Iteration 40
# New points: 0.19095477386934673
# Top 5%: 20.0
# Iteration 41
# New points: 0.3417085427135679
# Top 5%: 20.0
# Iteration 42
# New points: 0.19597989949748745
# Top 5%: 20.0
# Iteration 43
# New points: 0.14572864321608042
# Top 5%: 20.0
# Iteration 44
# New points: 0.11055276381909547
# Top 5%: 20.0
# Iteration 45
# New points: 0.35175879396984927
# Top 5%: 20.0
# Iteration 46
# New points: 0.04522613065326634
# Top 5%: 20.0
# Iteration 47
# New points: 0.32160804020100503
# Top 5%: 20.0
# Iteration 48
# New points: 0.16080402010050251
# Top 5%: 20.0
# Iteration 49
# New points: 0.1206030150753769
# Top 5%: 30.0
# Iteration 50
# New points: 0.1658291457286432
# Top 5%: 30.0
# Iteration 51
# New points: 0.47738693467336685
# Top 5%: 30.0
# Iteration 52
# New points: 0.09547738693467336
# Top 5%: 30.0
# Iteration 53
# New points: 0.34673366834170855
# Top 5%: 30.0
# Iteration 54
# New points: 0.4271356783919598
# Top 5%: 30.0
# Iteration 55
# New points: 0.1407035175879397
# Top 5%: 30.0
# Iteration 56
# New points: 0.17587939698492464
# Top 5%: 40.0
# Iteration 57
# New points: 0.20100502512562815
# Top 5%: 40.0
# Iteration 58
# New points: 0.1306532663316583
# Top 5%: 40.0
# Iteration 59
# New points: 0.07035175879396985
# Top 5%: 40.0
# Iteration 60
# New points: 0.18592964824120603
# Top 5%: 40.0
# Iteration 61
# New points: 0.17085427135678394
# Top 5%: 40.0
# Iteration 62
# New points: 0.1507537688442211
# Top 5%: 40.0
# Iteration 63
# New points: 0.11557788944723618
# Top 5%: 40.0
# Iteration 64
# New points: 0.33668341708542715
# Top 5%: 40.0
# Iteration 65
# New points: 0.1256281407035176
# Top 5%: 40.0
# Iteration 66
# New points: 0.3869346733668341
# Top 5%: 50.0
# Iteration 67
# New points: 0.9798994974874372
# Top 5%: 50.0
# Iteration 68
# New points: 0.9597989949748743
# Top 5%: 50.0
# Iteration 69
# New points: 0.4974874371859297
# Top 5%: 50.0
# Iteration 70
# New points: 0.8793969849246231
# Top 5%: 50.0
# Iteration 71
# New points: 0.15577889447236182
# Top 5%: 50.0
# Iteration 72
# New points: 0.4170854271356784
# Top 5%: 50.0
# Iteration 73
# New points: 0.18090452261306536
# Top 5%: 50.0
# Iteration 74
# New points: 0.3969849246231156
# Top 5%: 60.0
# Iteration 75
# New points: 0.4673366834170854
# Top 5%: 60.0
# Iteration 76
# New points: 0.8743718592964824
# Top 5%: 60.0
# Iteration 77
# New points: 0.07537688442211055
# Top 5%: 60.0
# Iteration 78
# New points: 0.6733668341708543
# Top 5%: 60.0
# Iteration 79
# New points: 0.35678391959798994
# Top 5%: 60.0
# Iteration 80
# New points: 0.10552763819095479
# Top 5%: 60.0
# Iteration 81
# New points: 0.9095477386934673
# Top 5%: 60.0
# Iteration 82
# New points: 0.9396984924623115
# Top 5%: 60.0
# Iteration 83
# New points: 0.3919597989949749
# Top 5%: 70.0
# Iteration 84
# New points: 0.5728643216080402
# Top 5%: 70.0
# Iteration 85
# New points: 0.507537688442211
# Top 5%: 70.0
# Iteration 86
# New points: 0.4020100502512563
# Top 5%: 70.0
# Iteration 87
# New points: 0.5125628140703518
# Top 5%: 70.0
# Iteration 88
# New points: 0.7788944723618091
# Top 5%: 70.0
# Iteration 89
# New points: 0.02512562814070352
# Top 5%: 70.0
# Iteration 90
# New points: 0.6130653266331658
# Top 5%: 70.0
# Iteration 91
# New points: 0.7236180904522614
# Top 5%: 70.0
# Iteration 92
# New points: 0.04020100502512563
# Top 5%: 70.0
# Iteration 93
# New points: 0.9949748743718594
# Top 5%: 70.0
# Iteration 94
# New points: 0.38190954773869346
# Top 5%: 80.0
# Iteration 95
# New points: 0.4723618090452262
# Top 5%: 80.0
# Iteration 96
# New points: 0.010050251256281407
# Top 5%: 80.0
# Iteration 97
# New points: 0.9748743718592965
# Top 5%: 80.0
# Iteration 98
# New points: 0.5979899497487438
# Top 5%: 80.0
# Iteration 99
# New points: 0.09045226130653268
# Top 5%: 80.0
# Iteration 100
# New points: 0.6180904522613065
# Top 5%: 80.0
# Iteration 101
# New points: 0.7135678391959799
# Top 5%: 80.0
# Iteration 102
# New points: 0.135678391959799
# Top 5%: 80.0
# Iteration 103
# New points: 0.05025125628140704
# Top 5%: 80.0
# Iteration 104
# New points: 0.5829145728643217
# Top 5%: 80.0
# Iteration 105
# New points: 0.4623115577889447
# Top 5%: 80.0
# Iteration 106
# New points: 0.48743718592964824
# Top 5%: 80.0
# Iteration 107
# New points: 0.5226130653266332
# Top 5%: 80.0
# Iteration 108
# New points: 0.7738693467336683
# Top 5%: 80.0
# Iteration 109
# New points: 0.40703517587939697
# Top 5%: 90.0
# Iteration 110
# New points: 0.44723618090452266
# Top 5%: 90.0
# Iteration 111
# New points: 0.9447236180904524
# Top 5%: 90.0
# Iteration 112
# New points: 0.4824120603015076
# Top 5%: 90.0
# Iteration 113
# New points: 0.7638190954773869
# Top 5%: 90.0
# Iteration 114
# New points: 0.42211055276381915
# Top 5%: 90.0
# Iteration 115
# New points: 0.015075376884422112
# Top 5%: 90.0
# Iteration 116
# New points: 0.7688442211055276
# Top 5%: 90.0
# Iteration 117
# New points: 0.9849246231155778
# Top 5%: 90.0
# Iteration 118
# New points: 0.08040201005025126
# Top 5%: 90.0
# Iteration 119
# New points: 0.7939698492462312
# Top 5%: 90.0
# Iteration 120
# New points: 0.592964824120603
# Top 5%: 90.0
# Iteration 121
# New points: 0.4321608040201005
# Top 5%: 90.0
# Iteration 122
# New points: 0.4120603015075377
# Top 5%: 90.0
# Iteration 123
# New points: 0.5326633165829145
# Top 5%: 90.0
# Iteration 124
# New points: 0.4371859296482412
# Top 5%: 90.0
# Iteration 125
# New points: 0.5276381909547739
# Top 5%: 90.0
# Iteration 126
# New points: 0.6331658291457287
# Top 5%: 90.0
# Iteration 127
# New points: 0.06532663316582915
# Top 5%: 90.0
# Iteration 128
# New points: 0.6482412060301508
# Top 5%: 90.0
# Iteration 129
# New points: 0.8994974874371859
# Top 5%: 90.0
# Iteration 130
# New points: 0.45226130653266333
# Top 5%: 90.0
# Iteration 131
# New points: 0.9547738693467337
# Top 5%: 90.0
# Iteration 132
# New points: 0.06030150753768845
# Top 5%: 90.0
# Iteration 133
# New points: 0.5628140703517588
# Top 5%: 90.0
# Iteration 134
# New points: 0.542713567839196
# Top 5%: 90.0
# Iteration 135
# New points: 0.5678391959798995
# Top 5%: 90.0
# Iteration 136
# New points: 0.030150753768844223
# Top 5%: 90.0
# Iteration 137
# New points: 0.020100502512562814
# Top 5%: 90.0
# Iteration 138
# New points: 0.5376884422110553
# Top 5%: 90.0
# Iteration 139
# New points: 0.8693467336683418
# Top 5%: 90.0
# Iteration 140
# New points: 0.5025125628140704
# Top 5%: 90.0
# Iteration 141
# New points: 0.6582914572864322
# Top 5%: 90.0
# Iteration 142
# New points: 0.7889447236180904
# Top 5%: 90.0
# Iteration 143
# New points: 0.914572864321608
# Top 5%: 90.0
# Iteration 144
# New points: 0.035175879396984924
# Top 5%: 90.0
# Iteration 145
# New points: 0.5577889447236181
# Top 5%: 90.0
# Iteration 146
# New points: 1.0
# Top 5%: 90.0
# Iteration 147
# New points: 0.5477386934673366
# Top 5%: 90.0
# Iteration 148
# New points: 0.7286432160804021
# Top 5%: 90.0
# Iteration 149
# New points: 0.949748743718593
# Top 5%: 90.0
# Iteration 150
# New points: 0.8894472361809045
# Top 5%: 90.0
# Iteration 151
# New points: 0.7437185929648241
# Top 5%: 90.0
# Iteration 152
# New points: 0.5527638190954774
# Top 5%: 90.0
# Iteration 153
# New points: 0.9899497487437187
# Top 5%: 90.0
# Iteration 154
# New points: 0.4924623115577889
# Top 5%: 90.0
# Iteration 155
# New points: 0.7989949748743718
# Top 5%: 90.0
# Iteration 156
# New points: 0.9346733668341708
# Top 5%: 90.0
# Iteration 157
# New points: 0.8492462311557789
# Top 5%: 90.0
# Iteration 158
# New points: 0.7386934673366834
# Top 5%: 90.0
# Iteration 159
# New points: 0.9195979899497488
# Top 5%: 90.0
# Iteration 160
# New points: 0.7839195979899498
# Top 5%: 90.0
# Iteration 161
# New points: 0.8944723618090453
# Top 5%: 90.0
# Iteration 162
# New points: 0.6432160804020101
# Top 5%: 90.0
# Iteration 163
# New points: 0.9296482412060302
# Top 5%: 90.0
# Iteration 164
# New points: 0.6532663316582914
# Top 5%: 90.0
# Iteration 165
# New points: 0.577889447236181
# Top 5%: 90.0
# Iteration 166
# New points: 0.9045226130653267
# Top 5%: 100.0
# Iterations 166
# Seed: 22
# Initial points: tensor([0.4422, 0.3719, 0.7186], dtype=torch.float64)
# Iteration 1
# New points: 0.005025125628140704
# Top 5%: 0.0
# Iteration 2
# New points: 0.2361809045226131
# Top 5%: 0.0
# Iteration 3
# New points: 0.29145728643216084
# Top 5%: 0.0
# Iteration 4
# New points: 0.16080402010050251
# Top 5%: 0.0
# Iteration 5
# New points: 1.0
# Top 5%: 0.0
# Iteration 6
# New points: 0.20100502512562815
# Top 5%: 0.0
# Iteration 7
# New points: 0.10050251256281408
# Top 5%: 0.0
# Iteration 8
# New points: 0.24623115577889446
# Top 5%: 0.0
# Iteration 9
# New points: 0.3969849246231156
# Top 5%: 10.0
# Iteration 10
# New points: 0.4020100502512563
# Top 5%: 10.0
# Iteration 11
# New points: 0.3919597989949749
# Top 5%: 20.0
# Iteration 12
# New points: 0.3869346733668341
# Top 5%: 30.0
# Iteration 13
# New points: 0.38190954773869346
# Top 5%: 40.0
# Iteration 14
# New points: 0.3768844221105528
# Top 5%: 50.0
# Iteration 15
# New points: 0.542713567839196
# Top 5%: 50.0
# Iteration 16
# New points: 0.8190954773869347
# Top 5%: 50.0
# Iteration 17
# New points: 0.9095477386934673
# Top 5%: 50.0
# Iteration 18
# New points: 0.6281407035175879
# Top 5%: 50.0
# Iteration 19
# New points: 0.4924623115577889
# Top 5%: 50.0
# Iteration 20
# New points: 0.7688442211055276
# Top 5%: 50.0
# Iteration 21
# New points: 0.055276381909547735
# Top 5%: 50.0
# Iteration 22
# New points: 0.9547738693467337
# Top 5%: 50.0
# Iteration 23
# New points: 0.864321608040201
# Top 5%: 50.0
# Iteration 24
# New points: 0.6733668341708543
# Top 5%: 50.0
# Iteration 25
# New points: 0.2663316582914573
# Top 5%: 50.0
# Iteration 26
# New points: 0.5829145728643217
# Top 5%: 50.0
# Iteration 27
# New points: 0.22110552763819094
# Top 5%: 50.0
# Iteration 28
# New points: 0.3266331658291457
# Top 5%: 50.0
# Iteration 29
# New points: 0.135678391959799
# Top 5%: 50.0
# Iteration 30
# New points: 0.18090452261306536
# Top 5%: 50.0
# Iteration 31
# New points: 0.4673366834170854
# Top 5%: 50.0
# Iteration 32
# New points: 0.030150753768844223
# Top 5%: 50.0
# Iteration 33
# New points: 0.08040201005025126
# Top 5%: 50.0
# Iteration 34
# New points: 0.5175879396984925
# Top 5%: 50.0
# Iteration 35
# New points: 0.3417085427135679
# Top 5%: 50.0
# Iteration 36
# New points: 0.31155778894472363
# Top 5%: 60.0
# Iteration 37
# New points: 0.7939698492462312
# Top 5%: 60.0
# Iteration 38
# New points: 0.1206030150753769
# Top 5%: 70.0
# Iteration 39
# New points: 0.7437185929648241
# Top 5%: 70.0
# Iteration 40
# New points: 0.9798994974874372
# Top 5%: 70.0
# Iteration 41
# New points: 0.9296482412060302
# Top 5%: 70.0
# Iteration 42
# New points: 0.2763819095477387
# Top 5%: 70.0
# Iteration 43
# New points: 0.8894472361809045
# Top 5%: 70.0
# Iteration 44
# New points: 0.6030150753768844
# Top 5%: 70.0
# Iteration 45
# New points: 0.2562814070351759
# Top 5%: 70.0
# Iteration 46
# New points: 0.8442211055276383
# Top 5%: 70.0
# Iteration 47
# New points: 0.6482412060301508
# Top 5%: 70.0
# Iteration 48
# New points: 0.21105527638190957
# Top 5%: 70.0
# Iteration 49
# New points: 0.3015075376884422
# Top 5%: 70.0
# Iteration 50
# New points: 0.6984924623115578
# Top 5%: 70.0
# Iteration 51
# New points: 0.11055276381909547
# Top 5%: 70.0
# Iteration 52
# New points: 0.1507537688442211
# Top 5%: 70.0
# Iteration 53
# New points: 0.4271356783919598
# Top 5%: 70.0
# Iteration 54
# New points: 0.5628140703517588
# Top 5%: 70.0
# Iteration 55
# New points: 0.19095477386934673
# Top 5%: 70.0
# Iteration 56
# New points: 0.17085427135678394
# Top 5%: 70.0
# Iteration 57
# New points: 0.04020100502512563
# Top 5%: 70.0
# Iteration 58
# New points: 0.020100502512562814
# Top 5%: 70.0
# Iteration 59
# New points: 0.35175879396984927
# Top 5%: 70.0
# Iteration 60
# New points: 0.07035175879396985
# Top 5%: 70.0
# Iteration 61
# New points: 0.09045226130653268
# Top 5%: 70.0
# Iteration 62
# New points: 0.45226130653266333
# Top 5%: 70.0
# Iteration 63
# New points: 0.5025125628140704
# Top 5%: 70.0
# Iteration 64
# New points: 0.4824120603015076
# Top 5%: 70.0
# Iteration 65
# New points: 0.5276381909547739
# Top 5%: 70.0
# Iteration 66
# New points: 0.4170854271356784
# Top 5%: 70.0
# Iteration 67
# New points: 0.9698492462311559
# Top 5%: 70.0
# Iteration 68
# New points: 0.9396984924623115
# Top 5%: 70.0
# Iteration 69
# New points: 0.6130653266331658
# Top 5%: 70.0
# Iteration 70
# New points: 0.8793969849246231
# Top 5%: 70.0
# Iteration 71
# New points: 0.9899497487437187
# Top 5%: 70.0
# Iteration 72
# New points: 0.8090452261306533
# Top 5%: 70.0
# Iteration 73
# New points: 0.8291457286432161
# Top 5%: 70.0
# Iteration 74
# New points: 0.7839195979899498
# Top 5%: 70.0
# Iteration 75
# New points: 0.31658291457286436
# Top 5%: 70.0
# Iteration 76
# New points: 0.7587939698492463
# Top 5%: 70.0
# Iteration 77
# New points: 0.7336683417085428
# Top 5%: 70.0
# Iteration 78
# New points: 0.1256281407035176
# Top 5%: 70.0
# Iteration 79
# New points: 0.6582914572864322
# Top 5%: 70.0
# Iteration 80
# New points: 0.6884422110552764
# Top 5%: 70.0
# Iteration 81
# New points: 0.9195979899497488
# Top 5%: 70.0
# Iteration 82
# New points: 0.8994974874371859
# Top 5%: 70.0
# Iteration 83
# New points: 0.2814070351758794
# Top 5%: 70.0
# Iteration 84
# New points: 0.23115577889447236
# Top 5%: 70.0
# Iteration 85
# New points: 0.592964824120603
# Top 5%: 70.0
# Iteration 86
# New points: 0.14572864321608042
# Top 5%: 70.0
# Iteration 87
# New points: 0.3316582914572864
# Top 5%: 70.0
# Iteration 88
# New points: 0.8542713567839196
# Top 5%: 70.0
# Iteration 89
# New points: 0.6381909547738693
# Top 5%: 70.0
# Iteration 90
# New points: 0.7085427135678393
# Top 5%: 70.0
# Iteration 91
# New points: 0.5527638190954774
# Top 5%: 70.0
# Iteration 92
# New points: 0.4321608040201005
# Top 5%: 70.0
# Iteration 93
# New points: 0.5728643216080402
# Top 5%: 70.0
# Iteration 94
# New points: 0.06532663316582915
# Top 5%: 70.0
# Iteration 95
# New points: 0.3065326633165829
# Top 5%: 70.0
# Iteration 96
# New points: 0.18592964824120603
# Top 5%: 70.0
# Iteration 97
# New points: 0.271356783919598
# Top 5%: 70.0
# Iteration 98
# New points: 0.21608040201005024
# Top 5%: 70.0
# Iteration 99
# New points: 0.2512562814070352
# Top 5%: 70.0
# Iteration 100
# New points: 0.11557788944723618
# Top 5%: 70.0
# Iteration 101
# New points: 0.20603015075376885
# Top 5%: 70.0
# Iteration 102
# New points: 0.0
# Top 5%: 70.0
# Iteration 103
# New points: 0.35678391959798994
# Top 5%: 70.0
# Iteration 104
# New points: 0.22613065326633167
# Top 5%: 70.0
# Iteration 105
# New points: 0.15577889447236182
# Top 5%: 70.0
# Iteration 106
# New points: 0.2412060301507538
# Top 5%: 70.0
# Iteration 107
# New points: 0.32160804020100503
# Top 5%: 70.0
# Iteration 108
# New points: 0.05025125628140704
# Top 5%: 70.0
# Iteration 109
# New points: 0.19597989949748745
# Top 5%: 70.0
# Iteration 110
# New points: 0.2613065326633166
# Top 5%: 70.0
# Iteration 111
# New points: 0.1407035175879397
# Top 5%: 70.0
# Iteration 112
# New points: 0.507537688442211
# Top 5%: 70.0
# Iteration 113
# New points: 0.42211055276381915
# Top 5%: 70.0
# Iteration 114
# New points: 0.015075376884422112
# Top 5%: 70.0
# Iteration 115
# New points: 0.2964824120603015
# Top 5%: 70.0
# Iteration 116
# New points: 0.10552763819095479
# Top 5%: 70.0
# Iteration 117
# New points: 0.5326633165829145
# Top 5%: 70.0
# Iteration 118
# New points: 0.457286432160804
# Top 5%: 70.0
# Iteration 119
# New points: 0.09547738693467336
# Top 5%: 70.0
# Iteration 120
# New points: 0.34673366834170855
# Top 5%: 70.0
# Iteration 121
# New points: 0.9648241206030151
# Top 5%: 70.0
# Iteration 122
# New points: 0.47738693467336685
# Top 5%: 70.0
# Iteration 123
# New points: 0.2864321608040201
# Top 5%: 70.0
# Iteration 124
# New points: 0.08542713567839197
# Top 5%: 70.0
# Iteration 125
# New points: 0.6633165829145728
# Top 5%: 70.0
# Iteration 126
# New points: 0.02512562814070352
# Top 5%: 70.0
# Iteration 127
# New points: 0.07537688442211055
# Top 5%: 70.0
# Iteration 128
# New points: 0.9447236180904524
# Top 5%: 70.0
# Iteration 129
# New points: 0.1306532663316583
# Top 5%: 70.0
# Iteration 130
# New points: 0.44723618090452266
# Top 5%: 70.0
# Iteration 131
# New points: 0.4371859296482412
# Top 5%: 70.0
# Iteration 132
# New points: 0.17587939698492464
# Top 5%: 80.0
# Iteration 133
# New points: 0.035175879396984924
# Top 5%: 80.0
# Iteration 134
# New points: 0.8693467336683418
# Top 5%: 80.0
# Iteration 135
# New points: 0.06030150753768845
# Top 5%: 80.0
# Iteration 136
# New points: 0.6180904522613065
# Top 5%: 80.0
# Iteration 137
# New points: 0.9949748743718594
# Top 5%: 80.0
# Iteration 138
# New points: 0.48743718592964824
# Top 5%: 80.0
# Iteration 139
# New points: 0.6834170854271358
# Top 5%: 80.0
# Iteration 140
# New points: 0.4974874371859297
# Top 5%: 80.0
# Iteration 141
# New points: 0.5477386934673366
# Top 5%: 80.0
# Iteration 142
# New points: 0.5376884422110553
# Top 5%: 80.0
# Iteration 143
# New points: 0.7788944723618091
# Top 5%: 80.0
# Iteration 144
# New points: 0.5226130653266332
# Top 5%: 80.0
# Iteration 145
# New points: 0.8341708542713568
# Top 5%: 80.0
# Iteration 146
# New points: 0.7487437185929647
# Top 5%: 80.0
# Iteration 147
# New points: 0.5577889447236181
# Top 5%: 80.0
# Iteration 148
# New points: 0.8040201005025126
# Top 5%: 80.0
# Iteration 149
# New points: 0.5125628140703518
# Top 5%: 80.0
# Iteration 150
# New points: 0.3618090452261307
# Top 5%: 80.0
# Iteration 151
# New points: 0.1658291457286432
# Top 5%: 80.0
# Iteration 152
# New points: 0.7236180904522614
# Top 5%: 80.0
# Iteration 153
# New points: 0.9849246231155778
# Top 5%: 80.0
# Iteration 154
# New points: 0.577889447236181
# Top 5%: 80.0
# Iteration 155
# New points: 0.33668341708542715
# Top 5%: 80.0
# Iteration 156
# New points: 0.6532663316582914
# Top 5%: 80.0
# Iteration 157
# New points: 0.04522613065326634
# Top 5%: 80.0
# Iteration 158
# New points: 0.914572864321608
# Top 5%: 80.0
# Iteration 159
# New points: 0.9748743718592965
# Top 5%: 80.0
# Iteration 160
# New points: 0.010050251256281407
# Top 5%: 80.0
# Iteration 161
# New points: 0.9597989949748743
# Top 5%: 80.0
# Iteration 162
# New points: 0.9346733668341708
# Top 5%: 80.0
# Iteration 163
# New points: 0.9246231155778895
# Top 5%: 80.0
# Iteration 164
# New points: 0.5979899497487438
# Top 5%: 80.0
# Iteration 165
# New points: 0.9045226130653267
# Top 5%: 90.0
# Iteration 166
# New points: 0.4120603015075377
# Top 5%: 90.0
# Iteration 167
# New points: 0.8844221105527638
# Top 5%: 90.0
# Iteration 168
# New points: 0.4623115577889447
# Top 5%: 90.0
# Iteration 169
# New points: 0.949748743718593
# Top 5%: 90.0
# Iteration 170
# New points: 0.6080402010050252
# Top 5%: 90.0
# Iteration 171
# New points: 0.5879396984924623
# Top 5%: 90.0
# Iteration 172
# New points: 0.6231155778894473
# Top 5%: 90.0
# Iteration 173
# New points: 0.8592964824120604
# Top 5%: 90.0
# Iteration 174
# New points: 0.6331658291457287
# Top 5%: 90.0
# Iteration 175
# New points: 0.6783919597989949
# Top 5%: 90.0
# Iteration 176
# New points: 0.8743718592964824
# Top 5%: 90.0
# Iteration 177
# New points: 0.6432160804020101
# Top 5%: 90.0
# Iteration 178
# New points: 0.7889447236180904
# Top 5%: 90.0
# Iteration 179
# New points: 0.7989949748743718
# Top 5%: 90.0
# Iteration 180
# New points: 0.8241206030150754
# Top 5%: 90.0
# Iteration 181
# New points: 0.7638190954773869
# Top 5%: 90.0
# Iteration 182
# New points: 0.4723618090452262
# Top 5%: 90.0
# Iteration 183
# New points: 0.6934673366834171
# Top 5%: 90.0
# Iteration 184
# New points: 0.7035175879396985
# Top 5%: 90.0
# Iteration 185
# New points: 0.8140703517587939
# Top 5%: 90.0
# Iteration 186
# New points: 0.8391959798994975
# Top 5%: 90.0
# Iteration 187
# New points: 0.7738693467336683
# Top 5%: 90.0
# Iteration 188
# New points: 0.7286432160804021
# Top 5%: 90.0
# Iteration 189
# New points: 0.7537688442211056
# Top 5%: 90.0
# Iteration 190
# New points: 0.8492462311557789
# Top 5%: 90.0
# Iteration 191
# New points: 0.7135678391959799
# Top 5%: 90.0
# Iteration 192
# New points: 0.7386934673366834
# Top 5%: 90.0
# Iteration 193
# New points: 0.3668341708542714
# Top 5%: 90.0
# Iteration 194
# New points: 0.5678391959798995
# Top 5%: 90.0
# Iteration 195
# New points: 0.6683417085427136
# Top 5%: 90.0
# Iteration 196
# New points: 0.40703517587939697
# Top 5%: 100.0
# Iterations 196
# Seed: 22
# Initial points: tensor([0.4422, 0.3719, 0.7186, 0.2111, 0.0050, 0.2663, 0.2965, 0.2613, 0.2513,
#         0.2714, 0.2864, 0.2563, 0.2764, 0.2915, 0.3065, 0.2362, 0.2462, 0.2312,
#         0.2412, 0.2261, 0.2211, 0.2814, 0.3015, 0.2161, 0.0854, 0.3166, 0.3266,
#         0.3769, 0.9698, 0.2060, 0.3618, 0.0553, 0.9648, 0.3668, 0.8643, 0.5176,
#         0.3116, 0.8543, 0.0000, 0.1005, 0.3317, 0.4573, 0.1910, 0.3417, 0.1960,
#         0.1457, 0.1106, 0.3518, 0.0452, 0.3216, 0.1608, 0.1206, 0.1658, 0.4774,
#         0.0955, 0.3467, 0.4271, 0.1407, 0.1759, 0.2010, 0.1307, 0.0704, 0.1859,
#         0.1709, 0.1508, 0.1156, 0.3367, 0.1256, 0.3869, 0.9799, 0.9598, 0.4975,
#         0.8794, 0.1558, 0.4171, 0.1809, 0.3970, 0.4673, 0.8744, 0.0754, 0.6734,
#         0.3568, 0.1055, 0.9095, 0.9397, 0.3920, 0.5729, 0.5075, 0.4020, 0.5126,
#         0.7789, 0.0251, 0.6131, 0.7236, 0.0402, 0.9950, 0.3819, 0.4724, 0.0101,
#         0.9749, 0.5980, 0.0905, 0.6181, 0.7136, 0.1357, 0.0503, 0.5829, 0.4623,
#         0.4874, 0.5226, 0.7739, 0.4070, 0.4472, 0.9447, 0.4824, 0.7638, 0.4221,
#         0.0151, 0.7688, 0.9849, 0.0804, 0.7940, 0.5930, 0.4322, 0.4121, 0.5327,
#         0.4372, 0.5276, 0.6332, 0.0653, 0.6482, 0.8995, 0.4523, 0.9548, 0.0603,
#         0.5628, 0.5427, 0.5678, 0.0302, 0.0201, 0.5377, 0.8693, 0.5025, 0.6583,
#         0.7889, 0.9146, 0.0352, 0.5578, 1.0000, 0.5477, 0.7286, 0.9497, 0.8894,
#         0.7437, 0.5528, 0.9899, 0.4925, 0.7990, 0.9347, 0.8492, 0.7387, 0.9196,
#         0.7839, 0.8945, 0.6432, 0.9296, 0.6533, 0.5779, 0.9045],
#        dtype=torch.float64)
# Iteration 1
# New points: 0.2613065326633166
# Top 5%: 0.0
# Iteration 2
# New points: 0.17587939698492464
# Top 5%: 10.0
# Iteration 3
# New points: 0.09547738693467336
# Top 5%: 10.0
# Iteration 4
# New points: 0.18592964824120603
# Top 5%: 10.0
# Iteration 5
# New points: 0.2663316582914573
# Top 5%: 10.0
# Iteration 6
# New points: 0.2562814070351759
# Top 5%: 10.0
# Iteration 7
# New points: 0.17085427135678394
# Top 5%: 10.0
# Iteration 8
# New points: 0.31155778894472363
# Top 5%: 20.0
# Iteration 9
# New points: 0.31658291457286436
# Top 5%: 20.0
# Iteration 10
# New points: 0.3065326633165829
# Top 5%: 20.0
# Iteration 11
# New points: 0.3015075376884422
# Top 5%: 20.0
# Iteration 12
# New points: 0.2964824120603015
# Top 5%: 20.0
# Iteration 13
# New points: 0.32160804020100503
# Top 5%: 20.0
# Iteration 14
# New points: 0.29145728643216084
# Top 5%: 20.0
# Iteration 15
# New points: 0.2864321608040201
# Top 5%: 20.0
# Iteration 16
# New points: 0.3316582914572864
# Top 5%: 20.0
# Iteration 17
# New points: 0.23115577889447236
# Top 5%: 20.0
# Iteration 18
# New points: 0.22613065326633167
# Top 5%: 20.0
# Iteration 19
# New points: 0.22110552763819094
# Top 5%: 20.0
# Iteration 20
# New points: 0.21608040201005024
# Top 5%: 20.0
# Iteration 21
# New points: 0.2361809045226131
# Top 5%: 20.0
# Iteration 22
# New points: 0.2412060301507538
# Top 5%: 20.0
# Iteration 23
# New points: 0.24623115577889446
# Top 5%: 20.0
# Iteration 24
# New points: 0.21105527638190957
# Top 5%: 20.0
# Iteration 25
# New points: 0.2512562814070352
# Top 5%: 20.0
# Iteration 26
# New points: 0.20603015075376885
# Top 5%: 20.0
# Iteration 27
# New points: 0.271356783919598
# Top 5%: 20.0
# Iteration 28
# New points: 0.2763819095477387
# Top 5%: 20.0
# Iteration 29
# New points: 0.2814070351758794
# Top 5%: 20.0
# Iteration 30
# New points: 0.20100502512562815
# Top 5%: 20.0
# Iteration 31
# New points: 0.19597989949748745
# Top 5%: 20.0
# Iteration 32
# New points: 0.3266331658291457
# Top 5%: 20.0
# Iteration 33
# New points: 1.0
# Top 5%: 20.0
# Iteration 34
# New points: 0.19095477386934673
# Top 5%: 20.0
# Iteration 35
# New points: 0.18090452261306536
# Top 5%: 20.0
# Iteration 36
# New points: 0.33668341708542715
# Top 5%: 20.0
# Iteration 37
# New points: 0.3417085427135679
# Top 5%: 20.0
# Iteration 38
# New points: 0.1658291457286432
# Top 5%: 20.0
# Iteration 39
# New points: 0.16080402010050251
# Top 5%: 20.0
# Iteration 40
# New points: 0.15577889447236182
# Top 5%: 20.0
# Iteration 41
# New points: 0.34673366834170855
# Top 5%: 20.0
# Iteration 42
# New points: 0.35175879396984927
# Top 5%: 20.0
# Iteration 43
# New points: 0.1507537688442211
# Top 5%: 20.0
# Iteration 44
# New points: 0.14572864321608042
# Top 5%: 20.0
# Iteration 45
# New points: 0.0
# Top 5%: 20.0
# Iteration 46
# New points: 0.1407035175879397
# Top 5%: 20.0
# Iteration 47
# New points: 0.135678391959799
# Top 5%: 20.0
# Iteration 48
# New points: 0.1306532663316583
# Top 5%: 20.0
# Iteration 49
# New points: 0.1256281407035176
# Top 5%: 20.0
# Iteration 50
# New points: 0.5477386934673366
# Top 5%: 20.0
# Iteration 51
# New points: 0.35678391959798994
# Top 5%: 20.0
# Iteration 52
# New points: 0.3668341708542714
# Top 5%: 20.0
# Iteration 53
# New points: 0.10050251256281408
# Top 5%: 20.0
# Iteration 54
# New points: 0.8894472361809045
# Top 5%: 20.0
# Iteration 55
# New points: 0.05025125628140704
# Top 5%: 20.0
# Iteration 56
# New points: 0.3618090452261307
# Top 5%: 20.0
# Iteration 57
# New points: 0.1206030150753769
# Top 5%: 30.0
# Iteration 58
# New points: 0.11557788944723618
# Top 5%: 30.0
# Iteration 59
# New points: 0.11055276381909547
# Top 5%: 30.0
# Iteration 60
# New points: 0.3768844221105528
# Top 5%: 40.0
# Iteration 61
# New points: 0.42211055276381915
# Top 5%: 40.0
# Iteration 62
# New points: 0.3969849246231156
# Top 5%: 50.0
# Iteration 63
# New points: 0.3869346733668341
# Top 5%: 60.0
# Iteration 64
# New points: 0.4020100502512563
# Top 5%: 60.0
# Iteration 65
# New points: 0.3919597989949749
# Top 5%: 70.0
# Iteration 66
# New points: 0.40703517587939697
# Top 5%: 80.0
# Iteration 67
# New points: 0.4120603015075377
# Top 5%: 80.0
# Iteration 68
# New points: 0.4170854271356784
# Top 5%: 80.0
# Iteration 69
# New points: 0.38190954773869346
# Top 5%: 90.0
# Iteration 70
# New points: 0.5025125628140704
# Top 5%: 90.0
# Iteration 71
# New points: 0.4271356783919598
# Top 5%: 90.0
# Iteration 72
# New points: 0.8090452261306533
# Top 5%: 90.0
# Iteration 73
# New points: 0.6130653266331658
# Top 5%: 90.0
# Iteration 74
# New points: 0.4924623115577889
# Top 5%: 90.0
# Iteration 75
# New points: 0.5175879396984925
# Top 5%: 90.0
# Iteration 76
# New points: 0.9447236180904524
# Top 5%: 90.0
# Iteration 77
# New points: 0.4321608040201005
# Top 5%: 90.0
# Iteration 78
# New points: 0.4371859296482412
# Top 5%: 90.0
# Iteration 79
# New points: 0.6683417085427136
# Top 5%: 90.0
# Iteration 80
# New points: 0.005025125628140704
# Top 5%: 90.0
# Iteration 81
# New points: 0.07035175879396985
# Top 5%: 90.0
# Iteration 82
# New points: 0.6030150753768844
# Top 5%: 90.0
# Iteration 83
# New points: 0.6080402010050252
# Top 5%: 90.0
# Iteration 84
# New points: 0.8291457286432161
# Top 5%: 90.0
# Iteration 85
# New points: 0.44723618090452266
# Top 5%: 90.0
# Iteration 86
# New points: 0.7688442211055276
# Top 5%: 90.0
# Iteration 87
# New points: 0.45226130653266333
# Top 5%: 90.0
# Iteration 88
# New points: 0.457286432160804
# Top 5%: 90.0
# Iteration 89
# New points: 0.9648241206030151
# Top 5%: 90.0
# Iteration 90
# New points: 0.8944723618090453
# Top 5%: 90.0
# Iteration 91
# New points: 0.010050251256281407
# Top 5%: 90.0
# Iteration 92
# New points: 0.015075376884422112
# Top 5%: 90.0
# Iteration 93
# New points: 0.864321608040201
# Top 5%: 90.0
# Iteration 94
# New points: 0.9949748743718594
# Top 5%: 90.0
# Iteration 95
# New points: 0.4623115577889447
# Top 5%: 90.0
# Iteration 96
# New points: 0.6733668341708543
# Top 5%: 90.0
# Iteration 97
# New points: 0.08542713567839197
# Top 5%: 90.0
# Iteration 98
# New points: 0.09045226130653268
# Top 5%: 90.0
# Iteration 99
# New points: 0.9346733668341708
# Top 5%: 90.0
# Iteration 100
# New points: 0.4723618090452262
# Top 5%: 90.0
# Iteration 101
# New points: 0.055276381909547735
# Top 5%: 90.0
# Iteration 102
# New points: 0.08040201005025126
# Top 5%: 90.0
# Iteration 103
# New points: 0.7437185929648241
# Top 5%: 90.0
# Iteration 104
# New points: 0.06030150753768845
# Top 5%: 90.0
# Iteration 105
# New points: 0.10552763819095479
# Top 5%: 90.0
# Iteration 106
# New points: 0.9899497487437187
# Top 5%: 90.0
# Iteration 107
# New points: 0.07537688442211055
# Top 5%: 90.0
# Iteration 108
# New points: 0.020100502512562814
# Top 5%: 90.0
# Iteration 109
# New points: 0.4673366834170854
# Top 5%: 90.0
# Iteration 110
# New points: 0.6281407035175879
# Top 5%: 90.0
# Iteration 111
# New points: 0.507537688442211
# Top 5%: 90.0
# Iteration 112
# New points: 0.02512562814070352
# Top 5%: 90.0
# Iteration 113
# New points: 0.8844221105527638
# Top 5%: 90.0
# Iteration 114
# New points: 0.9396984924623115
# Top 5%: 90.0
# Iteration 115
# New points: 0.7236180904522614
# Top 5%: 90.0
# Iteration 116
# New points: 0.9849246231155778
# Top 5%: 90.0
# Iteration 117
# New points: 0.5527638190954774
# Top 5%: 90.0
# Iteration 118
# New points: 0.5226130653266332
# Top 5%: 90.0
# Iteration 119
# New points: 0.06532663316582915
# Top 5%: 90.0
# Iteration 120
# New points: 0.47738693467336685
# Top 5%: 90.0
# Iteration 121
# New points: 0.6432160804020101
# Top 5%: 90.0
# Iteration 122
# New points: 0.04522613065326634
# Top 5%: 90.0
# Iteration 123
# New points: 0.5678391959798995
# Top 5%: 90.0
# Iteration 124
# New points: 0.6884422110552764
# Top 5%: 90.0
# Iteration 125
# New points: 0.5628140703517588
# Top 5%: 90.0
# Iteration 126
# New points: 0.4824120603015076
# Top 5%: 90.0
# Iteration 127
# New points: 0.9798994974874372
# Top 5%: 90.0
# Iteration 128
# New points: 0.4974874371859297
# Top 5%: 90.0
# Iteration 129
# New points: 0.9195979899497488
# Top 5%: 90.0
# Iteration 130
# New points: 0.5879396984924623
# Top 5%: 90.0
# Iteration 131
# New points: 0.04020100502512563
# Top 5%: 90.0
# Iteration 132
# New points: 0.7839195979899498
# Top 5%: 90.0
# Iteration 133
# New points: 0.8442211055276383
# Top 5%: 90.0
# Iteration 134
# New points: 0.030150753768844223
# Top 5%: 90.0
# Iteration 135
# New points: 0.7738693467336683
# Top 5%: 90.0
# Iteration 136
# New points: 0.5577889447236181
# Top 5%: 90.0
# Iteration 137
# New points: 0.48743718592964824
# Top 5%: 90.0
# Iteration 138
# New points: 0.9748743718592965
# Top 5%: 90.0
# Iteration 139
# New points: 0.9698492462311559
# Top 5%: 90.0
# Iteration 140
# New points: 0.035175879396984924
# Top 5%: 90.0
# Iteration 141
# New points: 0.5125628140703518
# Top 5%: 90.0
# Iteration 142
# New points: 0.6482412060301508
# Top 5%: 90.0
# Iteration 143
# New points: 0.949748743718593
# Top 5%: 90.0
# Iteration 144
# New points: 0.9597989949748743
# Top 5%: 90.0
# Iteration 145
# New points: 0.6532663316582914
# Top 5%: 90.0
# Iteration 146
# New points: 0.5276381909547739
# Top 5%: 90.0
# Iteration 147
# New points: 0.9547738693467337
# Top 5%: 90.0
# Iteration 148
# New points: 0.5326633165829145
# Top 5%: 90.0
# Iteration 149
# New points: 0.8241206030150754
# Top 5%: 90.0
# Iteration 150
# New points: 0.9045226130653267
# Top 5%: 100.0
# Iterations 150

# %%
# Visualization
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# First subplot: Student-T Process
ax1.fill_between(train_x.numpy(), (meanSTP - 2*stdSTP).numpy(), (meanSTP + 2*stdSTP).numpy(), color='grey', alpha=0.5, label='Uncertainty (lik-t GP)')
ax1.scatter(train_xSTP.numpy(), train_ySTP.numpy(), c='red', label="Student-T Process")
ax1.plot(train_x.numpy(), meanSTP.numpy(), 'b-', label="lik-t mean")
ax1.scatter(train_x.numpy(), train_y.numpy(), c='k', marker='.', label="Data")
ax1.scatter(initialPoints, initialPointsy, c='green', marker='o', label="Initial Points")
ax1.legend(loc="best")
ax1.set(xlabel="x", ylabel="y", title="Student-T Process with "+ acqFunc + " Acquisition Function")

# Second subplot: Gaussian Process
ax2.fill_between(train_x.numpy(), (meanEGP - 2*stdEGP).numpy(), (meanEGP + 2*stdEGP).numpy(), color='grey', alpha=0.5, label='Uncertainty (GP)')
ax2.scatter(train_xEGP.numpy(), train_yEGP.numpy(), c='red', label="Observed Points")
ax2.plot(train_x.numpy(), meanEGP.numpy(), 'b-', label="GP mean")
ax2.scatter(train_x.numpy(), train_y.numpy(), c='k', marker='.', label="Data")
ax2.scatter(initialPoints, initialPointsy, c='green', marker='o', label="Initial Points")
ax2.legend(loc="best")
ax2.set(xlabel="x", ylabel="y", title="Gaussian Process with "+ acqFunc + " Acquisition Function")

# Third subplot: Variational Gaussian Process
ax3.fill_between(train_x.numpy(), (meanVGP - 2*stdVGP).numpy(), (meanVGP + 2*stdVGP).numpy(), color='grey', alpha=0.5, label='Uncertainty (VGP)')
ax3.scatter(train_xVGP.numpy(), train_yVGP.numpy(), c='red', label="Observed Points")
ax3.plot(train_x.numpy(), meanVGP.numpy(), 'b-', label="VGP mean")
ax3.scatter(train_x.numpy(), train_y.numpy(), c='k', marker='.', label="Data")
ax3.scatter(initialPoints, initialPointsy, c='green', marker='o', label="Initial Points")
ax3.legend(loc="best")
ax3.set(xlabel="x", ylabel="y", title="Variational Gaussian Process with " + acqFunc + " Acquisition Function")

# Adjust layout
plt.tight_layout()
plt.show()
